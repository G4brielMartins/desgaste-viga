# %% [markdown]
# # --------------------------------
# # Instalação e importação de Dependências
# # --------------------------------

# %%
import keras
import os
import gdown
import numpy as np
import matplotlib.pyplot as plt

from keras import layers
from keras import backend as K
from keras import regularizers
from keras.callbacks import TensorBoard
# Out:
# WARNING:tensorflow:From c:\Users\jpsfb\miniconda3\envs\myenv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
os.getcwd()
# Out:
# 'c:\\Users\\jpsfb\\OneDrive\\Área de Trabalho\\LINSE\\Códigos'

# %%
print("teste")

# %%
# Coloquei uma pasta como visível (não editável) publicamente e peguei o link, da onde tirei a id usada no comando abaixo.
# O link é o seguinte: https://drive.google.com/drive/folders/1RaGjPb2wRcT1clvTqA-FdtkLJv_N-518
dados = gdown.download_folder(id="1RaGjPb2wRcT1clvTqA-FdtkLJv_N-518")
# Out:
# Retrieving folder contents
# Processing file 1efGMAZYypEiaQU8Zks05mj8g-fJY5OyX R1_A1_0.1.feather
# Processing file 14L9uNfd19PzP-Vh4CeD7AexmbvQz1u_O R1_A1_0.5.feather
# Processing file 1fyOEvRJlMPWsAgyE1I2GJp6jEgBTaEPC R1_A1_0.25.feather
# Processing file 1A2eGN3Wd1UG5CDunUKAUToaoQ7nA7BGB R1_A1_1.0.feather
# Processing file 138ynRoO-wsv3iMlw3k5_W93wVbCwn66i R2_A1_0.1.feather
# Processing file 1cuQPOCD-ikDnkITEXuhFcapRz3WjM7ms R2_A1_0.5.feather
# Processing file 1ActxF2BNWxJeB7rdPKqaKpIvUwJWLEsO R2_A1_0.25.feather
# Processing file 1eMW9E8fMcvz8wmq49xSXKcJg36R-D56K R2_A1_1.0.feather
# Processing file 1whnYFkQ2pqz0KUKBFALTjRz4gggVLThh R3_A1_0.1.feather
# Processing file 177GBUzd_t-sOn0b5WIgunNQdp5wDa-Ot R3_A1_0.5.feather
# Processing file 1NXZ7RXa0rPfFM5Sshu_fMh_Zz2TQaDIs R3_A1_0.25.feather
# Processing file 13gYMUFQYfI-YLF7GOu9CtXPoyHhfHasR R3_A1_1.0.feather
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1efGMAZYypEiaQU8Zks05mj8g-fJY5OyX
# To: c:\Users\jpsfb\OneDrive\Área de Trabalho\LINSE\Códigos\06Maio2024-Atuador1-Exp1-VigaIntacta\R1_A1_0.1.feather
# 100%|██████████| 1.91M/1.91M [00:11<00:00, 162kB/s]
# c:\Users\jpsfb\miniconda3\envs\myenv\Lib\site-packages\gdown\download.py:32: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = bs4.BeautifulSoup(line, features="html.parser")
# ---------------------------------------------------------------------------
# FileURLRetrievalError                     Traceback (most recent call last)
# File c:\Users\jpsfb\miniconda3\envs\myenv\Lib\site-packages\gdown\download.py:253, in download(url, output, quiet, proxy, speed, use_cookies, verify, id, fuzzy, resume, format, user_agent, log_messages)
#     252 try:
# --> 253     url = get_url_from_gdrive_confirmation(res.text)
#     254 except FileURLRetrievalError as e:
#
# File c:\Users\jpsfb\miniconda3\envs\myenv\Lib\site-packages\gdown\download.py:54, in get_url_from_gdrive_confirmation(contents)
#      53 if not url:
# ---> 54     raise FileURLRetrievalError(
#      55         "Cannot retrieve the public link of the file. "
#      56         "You may need to change the permission to "
#      57         "'Anyone with the link', or have had many accesses. "
#      58         "Check FAQ in https://github.com/wkentaro/gdown?tab=readme-ov-file#faq.",
#      59     )
#      60 return url
#
# FileURLRetrievalError: Cannot retrieve the public link of the file. You may need to change the permission to 'Anyone with the link', or have had many accesses. Check FAQ in https://github.com/wkentaro/gdown?tab=readme-ov-file#faq.
#
# During handling of the above exception, another exception occurred:
#
# FileURLRetrievalError                     Traceback (most recent call last)
# Cell In[19], line 3
#       1 # Coloquei uma pasta como visível (não editável) publicamente e peguei o link, da onde tirei a id usada no comando abaixo.
#       2 # O link é o seguinte: https://drive.google.com/drive/folders/1RaGjPb2wRcT1clvTqA-FdtkLJv_N-518
# ----> 3 dados = gdown.download_folder(id="1RaGjPb2wRcT1clvTqA-FdtkLJv_N-518")
#
# File c:\Users\jpsfb\miniconda3\envs\myenv\Lib\site-packages\gdown\download_folder.py:310, in download_folder(url, id, output, quiet, proxy, speed, use_cookies, remaining_ok, verify, user_agent, skip_download)
#     306     files.append(
#     307         GoogleDriveFileToDownload(id=id, path=path, local_path=local_path)
#     308     )
#     309 else:
# --> 310     local_path = download(
#     311         url="https://drive.google.com/uc?id=" + id,
#     312         output=local_path,
#     313         quiet=quiet,
#     314         proxy=proxy,
#     315         speed=speed,
#     316         use_cookies=use_cookies,
#     317         verify=verify,
#     318     )
#     319     if local_path is None:
#     320         if not quiet:
#
# File c:\Users\jpsfb\miniconda3\envs\myenv\Lib\site-packages\gdown\download.py:264, in download(url, output, quiet, proxy, speed, use_cookies, verify, id, fuzzy, resume, format, user_agent, log_messages)
#     254     except FileURLRetrievalError as e:
#     255         message = (
#     256             "Failed to retrieve file url:\n\n{}\n\n"
#     257             "You may still be able to access the file from the browser:"
#    (...)
#     262             url_origin,
#     263         )
# --> 264         raise FileURLRetrievalError(message)
#     266 filename_from_url = None
#     267 if gdrive_file_id and is_gdrive_download_link:
#
# FileURLRetrievalError: Failed to retrieve file url:
#
# 	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
# 	Check FAQ in https://github.com/wkentaro/gdown?tab=readme-ov-file#faq.
#
# You may still be able to access the file from the browser:
#
# 	https://drive.google.com/uc?id=14L9uNfd19PzP-Vh4CeD7AexmbvQz1u_O
#
# but Gdown can't. Please check connections and permissions.

# %% [markdown]
# # -----------------------
# # 1 - Simplest autoencoder
# # -----------------------

# %%
# This is the size of our encoded representations
encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

input_data = keras.Input(shape=(784,))

# "encoded" is the encoded representation of the input
encoded = layers.Dense(encoding_dim, activation='relu')(input_data)

# "decoded" is the lossy reconstruction of the input
decoded = layers.Dense(784, activation='sigmoid')(encoded)

# This model maps an input to its reconstruction
autoencoder = keras.Model(input_data, decoded)

# %%
# This model maps an input to its encoded representation

encoder = keras.Model(input_data, encoded)

# %%
# This is our encoded (32-dimensional) input
encoded_input = keras.Input(shape=(encoding_dim,))
# Retrieve the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-1]
# Create the decoder model
decoder = keras.Model(encoded_input, decoder_layer(encoded_input))

# %%
#configure our model to use a per-pixel binary crossentropy loss, and the Adam optimizer

autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
(x_train, _), (x_test, _) = dados
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 (x_train, _), (x_test, _) = id
#
# TypeError: cannot unpack non-iterable builtin_function_or_method object

# %%
#normalize all values between 0 and 1 and we will flatten the 28x28 images into vectors of size 784

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %%
#train our autoencoder for 50 epochs:

autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.2901 - val_loss: 0.2023
# Epoch 2/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1786 - val_loss: 0.1601
# Epoch 3/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1522 - val_loss: 0.1430
# Epoch 4/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1386 - val_loss: 0.1320
# Epoch 5/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1292 - val_loss: 0.1241
# Epoch 6/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1224 - val_loss: 0.1182
# Epoch 7/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1174 - val_loss: 0.1141
# Epoch 8/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1137 - val_loss: 0.1109
# Epoch 9/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1112 - val_loss: 0.1089
# Epoch 10/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1094 - val_loss: 0.1074
# Epoch 11/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1082 - val_loss: 0.1063
# Epoch 12/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1072 - val_loss: 0.1055
# Epoch 13/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1065 - val_loss: 0.1048
# Epoch 14/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1058 - val_loss: 0.1042
# Epoch 15/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1052 - val_loss: 0.1037
# Epoch 16/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1047 - val_loss: 0.1032
# Epoch 17/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1043 - val_loss: 0.1028
# Epoch 18/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1039 - val_loss: 0.1025
# Epoch 19/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1036 - val_loss: 0.1022
# Epoch 20/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1032 - val_loss: 0.1019
# Epoch 21/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1029 - val_loss: 0.1016
# Epoch 22/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1027 - val_loss: 0.1014
# Epoch 23/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1024 - val_loss: 0.1011
# Epoch 24/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1022 - val_loss: 0.1009
# Epoch 25/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1020 - val_loss: 0.1007
# Epoch 26/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1018 - val_loss: 0.1006
# Epoch 27/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1016 - val_loss: 0.1003
# Epoch 28/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1014 - val_loss: 0.1002
# Epoch 29/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1012 - val_loss: 0.1000
# Epoch 30/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1011 - val_loss: 0.0999
# Epoch 31/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1009 - val_loss: 0.0998
# Epoch 32/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1008 - val_loss: 0.0996
# Epoch 33/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1007 - val_loss: 0.0995
# Epoch 34/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1005 - val_loss: 0.0993
# Epoch 35/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1004 - val_loss: 0.0992
# Epoch 36/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1003 - val_loss: 0.0992
# Epoch 37/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1002 - val_loss: 0.0990
# Epoch 38/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1001 - val_loss: 0.0989
# Epoch 39/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1000 - val_loss: 0.0988
# Epoch 40/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0999 - val_loss: 0.0988
# Epoch 41/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0998 - val_loss: 0.0986
# Epoch 42/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0997 - val_loss: 0.0985
# Epoch 43/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0996 - val_loss: 0.0985
# Epoch 44/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0995 - val_loss: 0.0984
# Epoch 45/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0994 - val_loss: 0.0983
# Epoch 46/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0993 - val_loss: 0.0982
# Epoch 47/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0992 - val_loss: 0.0982
# Epoch 48/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0992 - val_loss: 0.0981
# Epoch 49/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0991 - val_loss: 0.0980
# Epoch 50/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0990 - val_loss: 0.0980

# %% [markdown]
# - After 50 epochs, the autoencoder seems to reach a stable train/validation loss value of about 0.09. We can try to visualize the reconstructed inputs and the encoded representations. We will use Matplotlib.

# %%
# Encode and decode some digits
# Note that we take them from the *test* set
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)
# Out:
# 313/313 [==============================] - 0s 710us/step
# 313/313 [==============================] - 0s 840us/step

# %% [markdown]
# # ----------------------
# # 1.1 - Usando Matplotlib
# # ----------------------

# %%
n = 10  # How many digits we will display
plt.figure(figsize=(20, 4))

for i in range(n):

    # Display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
plt.show()

# %% [markdown]
# # -------------------------------------------
# # 2 - Adding a sparsity constraint on the encoded representations
# # -------------------------------------------

# %%
encoding_dim = 32

input_img = keras.Input(shape=(784,))
# Add a Dense layer with a L1 activity regularizer
encoded = layers.Dense(encoding_dim, activation='relu',
                activity_regularizer=regularizers.l1(10e-5))(input_img)
decoded = layers.Dense(784, activation='sigmoid')(encoded)

autoencoder = keras.Model(input_img, decoded)

# %% [markdown]
# Parei em (https://blog.keras.io/building-autoencoders-in-keras.html)

# %% [markdown]
# # ----------------------------
# # 2.1 - Deep autoenconder
# # ----------------------------

# %%
input_img = keras.Input(shape=(784,))
encoded = layers.Dense(128, activation='relu')(input_img)
encoded = layers.Dense(64, activation='relu')(encoded)
encoded = layers.Dense(32, activation='relu')(encoded)

decoded = layers.Dense(64, activation='relu')(encoded)
decoded = layers.Dense(128, activation='relu')(decoded)
decoded = layers.Dense(784, activation='sigmoid')(decoded)

# %%
autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

autoencoder.fit(x_train, x_train,
                epochs=100,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2480 - val_loss: 0.1678
# Epoch 2/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1526 - val_loss: 0.1379
# Epoch 3/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1335 - val_loss: 0.1277
# Epoch 4/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1258 - val_loss: 0.1223
# Epoch 5/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1211 - val_loss: 0.1175
# Epoch 6/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1167 - val_loss: 0.1130
# Epoch 7/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1122 - val_loss: 0.1090
# Epoch 8/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1088 - val_loss: 0.1063
# Epoch 9/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1063 - val_loss: 0.1041
# Epoch 10/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1044 - val_loss: 0.1026
# Epoch 11/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1027 - val_loss: 0.1008
# Epoch 12/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1012 - val_loss: 0.0992
# Epoch 13/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0997 - val_loss: 0.0981
# Epoch 14/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0983 - val_loss: 0.0968
# Epoch 15/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0969 - val_loss: 0.0954
# Epoch 16/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0958 - val_loss: 0.0945
# Epoch 17/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0948 - val_loss: 0.0934
# Epoch 18/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0940 - val_loss: 0.0928
# Epoch 19/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0934 - val_loss: 0.0920
# Epoch 20/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0927 - val_loss: 0.0914
# Epoch 21/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0921 - val_loss: 0.0913
# Epoch 22/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0915 - val_loss: 0.0905
# Epoch 23/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0909 - val_loss: 0.0899
# Epoch 24/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0904 - val_loss: 0.0894
# Epoch 25/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0899 - val_loss: 0.0889
# Epoch 26/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0894 - val_loss: 0.0886
# Epoch 27/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0889 - val_loss: 0.0878
# Epoch 28/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0885 - val_loss: 0.0880
# Epoch 29/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0881 - val_loss: 0.0871
# Epoch 30/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0878 - val_loss: 0.0870
# Epoch 31/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0875 - val_loss: 0.0877
# Epoch 32/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0872 - val_loss: 0.0863
# Epoch 33/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0868 - val_loss: 0.0860
# Epoch 34/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0866 - val_loss: 0.0858
# Epoch 35/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0864 - val_loss: 0.0856
# Epoch 36/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0862 - val_loss: 0.0856
# Epoch 37/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0859 - val_loss: 0.0853
# Epoch 38/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0858 - val_loss: 0.0852
# Epoch 39/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0856 - val_loss: 0.0849
# Epoch 40/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0854 - val_loss: 0.0848
# Epoch 41/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0853 - val_loss: 0.0846
# Epoch 42/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0851 - val_loss: 0.0849
# Epoch 43/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0850 - val_loss: 0.0844
# Epoch 44/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0849 - val_loss: 0.0842
# Epoch 45/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0847 - val_loss: 0.0841
# Epoch 46/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0846 - val_loss: 0.0841
# Epoch 47/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0844 - val_loss: 0.0839
# Epoch 48/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0843 - val_loss: 0.0837
# Epoch 49/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0842 - val_loss: 0.0837
# Epoch 50/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0841 - val_loss: 0.0836
# Epoch 51/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0840 - val_loss: 0.0836
# Epoch 52/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0838 - val_loss: 0.0834
# Epoch 53/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0837 - val_loss: 0.0833
# Epoch 54/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0836 - val_loss: 0.0832
# Epoch 55/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0835 - val_loss: 0.0829
# Epoch 56/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0834 - val_loss: 0.0829
# Epoch 57/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0833 - val_loss: 0.0830
# Epoch 58/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0832 - val_loss: 0.0828
# Epoch 59/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0831 - val_loss: 0.0829
# Epoch 60/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0831 - val_loss: 0.0830
# Epoch 61/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0829 - val_loss: 0.0825
# Epoch 62/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0829 - val_loss: 0.0827
# Epoch 63/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0828 - val_loss: 0.0822
# Epoch 64/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0827 - val_loss: 0.0824
# Epoch 65/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0827 - val_loss: 0.0822
# Epoch 66/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0826 - val_loss: 0.0822
# Epoch 67/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0825 - val_loss: 0.0821
# Epoch 68/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0825 - val_loss: 0.0821
# Epoch 69/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0824 - val_loss: 0.0820
# Epoch 70/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0823 - val_loss: 0.0821
# Epoch 71/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0823 - val_loss: 0.0820
# Epoch 72/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0822 - val_loss: 0.0819
# Epoch 73/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0822 - val_loss: 0.0819
# Epoch 74/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0821 - val_loss: 0.0818
# Epoch 75/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0821 - val_loss: 0.0818
# Epoch 76/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0820 - val_loss: 0.0817
# Epoch 77/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0820 - val_loss: 0.0817
# Epoch 78/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0820 - val_loss: 0.0818
# Epoch 79/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0819 - val_loss: 0.0817
# Epoch 80/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0819 - val_loss: 0.0816
# Epoch 81/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0818 - val_loss: 0.0814
# Epoch 82/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0818 - val_loss: 0.0817
# Epoch 83/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0818 - val_loss: 0.0816
# Epoch 84/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0817 - val_loss: 0.0814
# Epoch 85/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0816 - val_loss: 0.0813
# Epoch 86/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0817 - val_loss: 0.0814
# Epoch 87/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0816 - val_loss: 0.0813
# Epoch 88/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0816 - val_loss: 0.0812
# Epoch 89/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0815 - val_loss: 0.0813
# Epoch 90/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0815 - val_loss: 0.0811
# Epoch 91/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0815 - val_loss: 0.0814
# Epoch 92/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0814 - val_loss: 0.0814
# Epoch 93/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0814 - val_loss: 0.0810
# Epoch 94/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0814 - val_loss: 0.0811
# Epoch 95/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0814 - val_loss: 0.0812
# Epoch 96/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0813 - val_loss: 0.0811
# Epoch 97/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0813 - val_loss: 0.0812
# Epoch 98/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0813 - val_loss: 0.0812
# Epoch 99/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0813 - val_loss: 0.0815
# Epoch 100/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0812 - val_loss: 0.0812

# %% [markdown]
# # ----------------------
# # 2.2 - Usando Matplotlib
# # ----------------------

# %%
n = 10  # How many digits we will display
plt.figure(figsize=(20, 4))

for i in range(n):

    # Display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
plt.show()

# %% [markdown]
# # --------------------------------
# # 3 - Convolutional autoenconder
# # --------------------------------

# %%
input_img = keras.Input(shape=(28, 28, 1))

x = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same')(x)

# at this point the representation is (4, 4, 8) i.e. 128-dimensional

x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(16, (3, 3), activation='relu')(x)
x = layers.UpSampling2D((2, 2))(x)
decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
# Out:
# WARNING:tensorflow:From c:\Users\jpsfb\miniconda3\envs\myenv\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

# %% [markdown]
# # Abrir terminal e rodar o código abaixo

# %%
tensorboard --logdir=/tmp/autoencoder

# para visualizar resultados do modelo durante o treinamento
# copiar path que o CMD retorna e colar no browser para visualizar

# %%
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test, x_test),
                callbacks=[TensorBoard(log_dir='/tmp/autoencoder')])
# Out:
# Epoch 1/50
# 469/469 [==============================] - 8s 15ms/step - loss: 0.2059 - val_loss: 0.1478
# Epoch 2/50
# 469/469 [==============================] - 8s 17ms/step - loss: 0.1394 - val_loss: 0.1309
# Epoch 3/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1270 - val_loss: 0.1215
# Epoch 4/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1200 - val_loss: 0.1165
# Epoch 5/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1154 - val_loss: 0.1125
# Epoch 6/50
# 469/469 [==============================] - 8s 16ms/step - loss: 0.1121 - val_loss: 0.1101
# Epoch 7/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1096 - val_loss: 0.1070
# Epoch 8/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1076 - val_loss: 0.1057
# Epoch 9/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1061 - val_loss: 0.1042
# Epoch 10/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1048 - val_loss: 0.1037
# Epoch 11/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1037 - val_loss: 0.1017
# Epoch 12/50
# 469/469 [==============================] - 7s 16ms/step - loss: 0.1028 - val_loss: 0.1013
# Epoch 13/50
# 469/469 [==============================] - 8s 16ms/step - loss: 0.1019 - val_loss: 0.1008
# Epoch 14/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1014 - val_loss: 0.0996
# Epoch 15/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1007 - val_loss: 0.0991
# Epoch 16/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1002 - val_loss: 0.0984
# Epoch 17/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0998 - val_loss: 0.0981
# Epoch 18/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0993 - val_loss: 0.0982
# Epoch 19/50
# 469/469 [==============================] - 7s 14ms/step - loss: 0.0988 - val_loss: 0.0973
# Epoch 20/50
# 469/469 [==============================] - 7s 14ms/step - loss: 0.0984 - val_loss: 0.0972
# Epoch 21/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0981 - val_loss: 0.0966
# Epoch 22/50
# 469/469 [==============================] - 7s 14ms/step - loss: 0.0977 - val_loss: 0.0963
# Epoch 23/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0974 - val_loss: 0.0959
# Epoch 24/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0970 - val_loss: 0.0957
# Epoch 25/50
# 469/469 [==============================] - 7s 14ms/step - loss: 0.0968 - val_loss: 0.0955
# Epoch 26/50
# 469/469 [==============================] - 7s 14ms/step - loss: 0.0965 - val_loss: 0.0951
# Epoch 27/50
# 469/469 [==============================] - 7s 14ms/step - loss: 0.0961 - val_loss: 0.0948
# Epoch 28/50
# 469/469 [==============================] - 7s 14ms/step - loss: 0.0959 - val_loss: 0.0947
# Epoch 29/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0957 - val_loss: 0.0952
# Epoch 30/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0955 - val_loss: 0.0950
# Epoch 31/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0952 - val_loss: 0.0943
# Epoch 32/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0950 - val_loss: 0.0939
# Epoch 33/50
# 469/469 [==============================] - 7s 14ms/step - loss: 0.0948 - val_loss: 0.0936
# Epoch 34/50
# 469/469 [==============================] - 7s 14ms/step - loss: 0.0947 - val_loss: 0.0936
# Epoch 35/50
# 469/469 [==============================] - 7s 14ms/step - loss: 0.0944 - val_loss: 0.0930
# Epoch 36/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0942 - val_loss: 0.0928
# Epoch 37/50
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0941 - val_loss: 0.0929
# Epoch 38/50
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0939 - val_loss: 0.0926
# Epoch 39/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0937 - val_loss: 0.0925
# Epoch 40/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0935 - val_loss: 0.0923
# Epoch 41/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0934 - val_loss: 0.0921
# Epoch 42/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0932 - val_loss: 0.0929
# Epoch 43/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0931 - val_loss: 0.0919
# Epoch 44/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 45/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0927 - val_loss: 0.0918
# Epoch 46/50
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0927 - val_loss: 0.0914
# Epoch 47/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0925 - val_loss: 0.0914
# Epoch 48/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0924 - val_loss: 0.0912
# Epoch 49/50
# 469/469 [==============================] - 7s 14ms/step - loss: 0.0923 - val_loss: 0.0920
# Epoch 50/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0921 - val_loss: 0.0915

# %%
decoded_imgs = autoencoder.predict(x_test)

n = 10
plt.figure(figsize=(20, 4))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %%
encoder = keras.Model(input_img, encoded)
encoded_imgs = encoder.predict(x_test)

n = 10
plt.figure(figsize=(20, 8))
for i in range(1, n + 1):
    ax = plt.subplot(1, n, i)
    plt.imshow(encoded_imgs[i].reshape((4, 4 * 8)).T)
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# 313/313 [==============================] - 1s 1ms/step

# %% [markdown]
# # ---------------------
# # 4 - Application to image denoising
# # ---------------------

# %%
(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape) 
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape) 

x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

# %%
n = 10
plt.figure(figsize=(20, 2))
for i in range(1, n + 1):
    ax = plt.subplot(1, n, i)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
input_img = keras.Input(shape=(28, 28, 1))

x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same')(x)

# At this point the representation is (7, 7, 32)

x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(encoded)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
autoencoder.fit(x_train_noisy, x_train,
                epochs=100,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test_noisy, x_test),
                callbacks=[TensorBoard(log_dir='/tmp/tb', histogram_freq=0, write_graph=False)])
# Out:
# Epoch 1/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0960 - val_loss: 0.0951
# Epoch 2/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0959 - val_loss: 0.0951
# Epoch 3/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0957 - val_loss: 0.0949
# Epoch 4/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0956 - val_loss: 0.0949
# Epoch 5/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0955 - val_loss: 0.0948
# Epoch 6/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0954 - val_loss: 0.0946
# Epoch 7/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0953 - val_loss: 0.0949
# Epoch 8/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0953 - val_loss: 0.0946
# Epoch 9/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0951 - val_loss: 0.0952
# Epoch 10/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0951 - val_loss: 0.0945
# Epoch 11/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0950 - val_loss: 0.0945
# Epoch 12/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0949 - val_loss: 0.0944
# Epoch 13/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0949 - val_loss: 0.0943
# Epoch 14/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0948 - val_loss: 0.0944
# Epoch 15/100
# 469/469 [==============================] - 14s 29ms/step - loss: 0.0948 - val_loss: 0.0942
# Epoch 16/100
# 469/469 [==============================] - 14s 29ms/step - loss: 0.0947 - val_loss: 0.0942
# Epoch 17/100
# 469/469 [==============================] - 14s 29ms/step - loss: 0.0947 - val_loss: 0.0941
# Epoch 18/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0946 - val_loss: 0.0942
# Epoch 19/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0946 - val_loss: 0.0943
# Epoch 20/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0946 - val_loss: 0.0940
# Epoch 21/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0946 - val_loss: 0.0941
# Epoch 22/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0945 - val_loss: 0.0939
# Epoch 23/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0944 - val_loss: 0.0941
# Epoch 24/100
# 469/469 [==============================] - 13s 29ms/step - loss: 0.0944 - val_loss: 0.0940
# Epoch 25/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0944 - val_loss: 0.0939
# Epoch 26/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0943 - val_loss: 0.0939
# Epoch 27/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0943 - val_loss: 0.0939
# Epoch 28/100
# 469/469 [==============================] - 14s 29ms/step - loss: 0.0943 - val_loss: 0.0939
# Epoch 29/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0942 - val_loss: 0.0939
# Epoch 30/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0943 - val_loss: 0.0938
# Epoch 31/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0942 - val_loss: 0.0942
# Epoch 32/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0941 - val_loss: 0.0938
# Epoch 33/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0942 - val_loss: 0.0938
# Epoch 34/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0941 - val_loss: 0.0940
# Epoch 35/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0941 - val_loss: 0.0938
# Epoch 36/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0941 - val_loss: 0.0936
# Epoch 37/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0941 - val_loss: 0.0936
# Epoch 38/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0941 - val_loss: 0.0936
# Epoch 39/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0940 - val_loss: 0.0937
# Epoch 40/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0940 - val_loss: 0.0936
# Epoch 41/100
# 469/469 [==============================] - 14s 29ms/step - loss: 0.0940 - val_loss: 0.0946
# Epoch 42/100
# 469/469 [==============================] - 15s 32ms/step - loss: 0.0940 - val_loss: 0.0942
# Epoch 43/100
# 469/469 [==============================] - 16s 33ms/step - loss: 0.0940 - val_loss: 0.0937
# Epoch 44/100
# 469/469 [==============================] - 14s 29ms/step - loss: 0.0939 - val_loss: 0.0936
# Epoch 45/100
# 469/469 [==============================] - 14s 30ms/step - loss: 0.0939 - val_loss: 0.0937
# Epoch 46/100
# 469/469 [==============================] - 14s 31ms/step - loss: 0.0939 - val_loss: 0.0935
# Epoch 47/100
# 469/469 [==============================] - 14s 30ms/step - loss: 0.0939 - val_loss: 0.0936
# Epoch 48/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0939 - val_loss: 0.0935
# Epoch 49/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0938 - val_loss: 0.0936
# Epoch 50/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0938 - val_loss: 0.0937
# Epoch 51/100
# 469/469 [==============================] - 14s 30ms/step - loss: 0.0939 - val_loss: 0.0935
# Epoch 52/100
# 469/469 [==============================] - 14s 30ms/step - loss: 0.0938 - val_loss: 0.0934
# Epoch 53/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0938 - val_loss: 0.0935
# Epoch 54/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0937 - val_loss: 0.0935
# Epoch 55/100
# 469/469 [==============================] - 13s 29ms/step - loss: 0.0938 - val_loss: 0.0934
# Epoch 56/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0937 - val_loss: 0.0937
# Epoch 57/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0937 - val_loss: 0.0941
# Epoch 58/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0937 - val_loss: 0.0934
# Epoch 59/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0937 - val_loss: 0.0936
# Epoch 60/100
# 469/469 [==============================] - 14s 29ms/step - loss: 0.0937 - val_loss: 0.0934
# Epoch 61/100
# 469/469 [==============================] - 14s 30ms/step - loss: 0.0937 - val_loss: 0.0936
# Epoch 62/100
# 469/469 [==============================] - 14s 29ms/step - loss: 0.0937 - val_loss: 0.0934
# Epoch 63/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0937 - val_loss: 0.0934
# Epoch 64/100
# 469/469 [==============================] - 14s 29ms/step - loss: 0.0936 - val_loss: 0.0934
# Epoch 65/100
# 469/469 [==============================] - 14s 29ms/step - loss: 0.0936 - val_loss: 0.0933
# Epoch 66/100
# 469/469 [==============================] - 14s 30ms/step - loss: 0.0936 - val_loss: 0.0937
# Epoch 67/100
# 469/469 [==============================] - 14s 30ms/step - loss: 0.0936 - val_loss: 0.0933
# Epoch 68/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0935 - val_loss: 0.0937
# Epoch 69/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0936 - val_loss: 0.0935
# Epoch 70/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0936 - val_loss: 0.0933
# Epoch 71/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0935 - val_loss: 0.0935
# Epoch 72/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0935 - val_loss: 0.0933
# Epoch 73/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0935 - val_loss: 0.0934
# Epoch 74/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0935 - val_loss: 0.0937
# Epoch 75/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0935 - val_loss: 0.0934
# Epoch 76/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0935 - val_loss: 0.0934
# Epoch 77/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0935 - val_loss: 0.0932
# Epoch 78/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0935 - val_loss: 0.0932
# Epoch 79/100
# 469/469 [==============================] - 14s 30ms/step - loss: 0.0935 - val_loss: 0.0933
# Epoch 80/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0934 - val_loss: 0.0932
# Epoch 81/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0934 - val_loss: 0.0933
# Epoch 82/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0935 - val_loss: 0.0932
# Epoch 83/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0934 - val_loss: 0.0934
# Epoch 84/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0934 - val_loss: 0.0935
# Epoch 85/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0934 - val_loss: 0.0932
# Epoch 86/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0934 - val_loss: 0.0933
# Epoch 87/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0934 - val_loss: 0.0934
# Epoch 88/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0934 - val_loss: 0.0933
# Epoch 89/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0934 - val_loss: 0.0931
# Epoch 90/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0934 - val_loss: 0.0932
# Epoch 91/100
# 469/469 [==============================] - 13s 29ms/step - loss: 0.0934 - val_loss: 0.0933
# Epoch 92/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0934 - val_loss: 0.0931
# Epoch 93/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0933 - val_loss: 0.0932
# Epoch 94/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0933 - val_loss: 0.0933
# Epoch 95/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0933 - val_loss: 0.0932
# Epoch 96/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0933 - val_loss: 0.0932
# Epoch 97/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0933 - val_loss: 0.0933
# Epoch 98/100
# 469/469 [==============================] - 13s 29ms/step - loss: 0.0933 - val_loss: 0.0931
# Epoch 99/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0933 - val_loss: 0.0932
# Epoch 100/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0933 - val_loss: 0.0934

# %%
n = 10
plt.figure(figsize=(20, 2))
for i in range(1, n + 1):
    ax = plt.subplot(1, n, i)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# # -----------------------
# # 5 - Variational autoencoder (VAE)
# # -----------------------

# %%
original_dim = 28 * 28
intermediate_dim = 64
latent_dim = 2

inputs = keras.Input(shape=(original_dim,))
h = layers.Dense(intermediate_dim, activation='relu')(inputs)
z_mean = layers.Dense(latent_dim)(h)
z_log_sigma = layers.Dense(latent_dim)(h)

# %%
def sampling(args):
    z_mean, z_log_sigma = args
    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], latent_dim),
                              mean=0., stddev=0.1)
    return z_mean + K.exp(z_log_sigma) * epsilon

z = layers.Lambda(sampling)([z_mean, z_log_sigma])

# %%
# Create encoder
encoder = keras.Model(inputs, [z_mean, z_log_sigma, z], name='encoder')

# Create decoder
latent_inputs = keras.Input(shape=(latent_dim,), name='z_sampling')
x = layers.Dense(intermediate_dim, activation='relu')(latent_inputs)
outputs = layers.Dense(original_dim, activation='sigmoid')(x)
decoder = keras.Model(latent_inputs, outputs, name='decoder')

# instantiate VAE model
outputs = decoder(encoder(inputs)[2])
vae = keras.Model(inputs, outputs, name='vae_mlp')

# %%
reconstruction_loss = keras.losses.binary_crossentropy(inputs, outputs)
reconstruction_loss *= original_dim
kl_loss = 1 + z_log_sigma - K.square(z_mean) - K.exp(z_log_sigma)
kl_loss = K.sum(kl_loss, axis=-1)
kl_loss *= -0.5
vae_loss = K.mean(reconstruction_loss + kl_loss)
vae.add_loss(vae_loss)
vae.compile(optimizer='adam')

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

vae.fit(x_train, x_train,
        epochs=100,
        batch_size=32,
        validation_data=(x_test, x_test))
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 188.0148 - val_loss: 168.8074
# Epoch 2/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 166.1743 - val_loss: 163.8458
# Epoch 3/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 162.3086 - val_loss: 161.1385
# Epoch 4/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 159.7469 - val_loss: 158.7795
# Epoch 5/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 157.7067 - val_loss: 157.0922
# Epoch 6/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 156.1033 - val_loss: 155.6340
# Epoch 7/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 154.9737 - val_loss: 154.7472
# Epoch 8/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 154.1580 - val_loss: 154.0456
# Epoch 9/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 153.4978 - val_loss: 153.5186
# Epoch 10/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 152.9128 - val_loss: 153.0824
# Epoch 11/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 152.3994 - val_loss: 152.4460
# Epoch 12/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 151.9446 - val_loss: 152.1912
# Epoch 13/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 151.5659 - val_loss: 151.8976
# Epoch 14/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 151.2110 - val_loss: 151.4540
# Epoch 15/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 150.8849 - val_loss: 151.3222
# Epoch 16/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 150.5961 - val_loss: 150.9735
# Epoch 17/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 150.3794 - val_loss: 150.7738
# Epoch 18/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 150.0992 - val_loss: 150.5893
# Epoch 19/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 149.8590 - val_loss: 150.5573
# Epoch 20/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 149.6853 - val_loss: 150.1189
# Epoch 21/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 149.4751 - val_loss: 150.2672
# Epoch 22/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 149.3048 - val_loss: 150.2341
# Epoch 23/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 149.1304 - val_loss: 149.8071
# Epoch 24/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 148.9672 - val_loss: 149.6237
# Epoch 25/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 148.8074 - val_loss: 149.4241
# Epoch 26/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 148.6944 - val_loss: 149.4689
# Epoch 27/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 148.5417 - val_loss: 149.2502
# Epoch 28/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 148.4233 - val_loss: 149.1633
# Epoch 29/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 148.2969 - val_loss: 149.1530
# Epoch 30/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 148.1524 - val_loss: 148.9449
# Epoch 31/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 148.0767 - val_loss: 148.8662
# Epoch 32/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 147.9342 - val_loss: 148.9663
# Epoch 33/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 147.8468 - val_loss: 148.6858
# Epoch 34/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 147.7581 - val_loss: 148.7025
# Epoch 35/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 147.6381 - val_loss: 148.5509
# Epoch 36/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 147.5444 - val_loss: 148.5113
# Epoch 37/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 147.4574 - val_loss: 148.4692
# Epoch 38/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 147.3838 - val_loss: 148.5707
# Epoch 39/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 147.2784 - val_loss: 148.3390
# Epoch 40/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 147.1690 - val_loss: 148.3164
# Epoch 41/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 147.0775 - val_loss: 148.1163
# Epoch 42/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 147.0115 - val_loss: 148.7679
# Epoch 43/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 146.9455 - val_loss: 148.3068
# Epoch 44/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 146.8279 - val_loss: 148.1064
# Epoch 45/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 146.7586 - val_loss: 148.1897
# Epoch 46/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 146.7025 - val_loss: 147.9033
# Epoch 47/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 146.6023 - val_loss: 148.0239
# Epoch 48/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 146.5444 - val_loss: 147.8655
# Epoch 49/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 146.5019 - val_loss: 147.7851
# Epoch 50/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 146.4289 - val_loss: 147.8161
# Epoch 51/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 146.3414 - val_loss: 147.9495
# Epoch 52/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 146.2662 - val_loss: 147.6919
# Epoch 53/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 146.2023 - val_loss: 147.4911
# Epoch 54/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 146.1717 - val_loss: 147.8921
# Epoch 55/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 146.1239 - val_loss: 147.8812
# Epoch 56/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 146.0490 - val_loss: 147.8650
# Epoch 57/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 145.9670 - val_loss: 147.6305
# Epoch 58/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 145.9418 - val_loss: 147.3730
# Epoch 59/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 145.9024 - val_loss: 147.3993
# Epoch 60/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 145.7941 - val_loss: 147.7428
# Epoch 61/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 145.7832 - val_loss: 147.3820
# Epoch 62/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 145.6946 - val_loss: 147.2214
# Epoch 63/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 145.6714 - val_loss: 147.4694
# Epoch 64/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 145.6066 - val_loss: 147.3035
# Epoch 65/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 145.5519 - val_loss: 147.3338
# Epoch 66/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 145.5335 - val_loss: 147.2085
# Epoch 67/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 145.4572 - val_loss: 147.4815
# Epoch 68/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 145.4111 - val_loss: 147.0960
# Epoch 69/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 145.3524 - val_loss: 147.2245
# Epoch 70/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 145.3024 - val_loss: 147.3430
# Epoch 71/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 145.2889 - val_loss: 146.8960
# Epoch 72/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 145.2523 - val_loss: 147.2853
# Epoch 73/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 145.2190 - val_loss: 147.0905
# Epoch 74/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 145.1617 - val_loss: 147.0209
# Epoch 75/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 145.0949 - val_loss: 147.1816
# Epoch 76/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 145.0868 - val_loss: 147.0014
# Epoch 77/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 145.0290 - val_loss: 146.9265
# Epoch 78/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 144.9933 - val_loss: 146.8521
# Epoch 79/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 144.9611 - val_loss: 146.6959
# Epoch 80/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 144.9294 - val_loss: 146.9562
# Epoch 81/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 144.8875 - val_loss: 146.8687
# Epoch 82/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 144.8728 - val_loss: 146.8878
# Epoch 83/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 144.8070 - val_loss: 146.8645
# Epoch 84/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 144.8111 - val_loss: 147.1240
# Epoch 85/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 144.7782 - val_loss: 147.1233
# Epoch 86/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 144.7592 - val_loss: 146.7974
# Epoch 87/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 144.7104 - val_loss: 146.8390
# Epoch 88/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 144.6873 - val_loss: 146.7814
# Epoch 89/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 144.6588 - val_loss: 146.7778
# Epoch 90/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 144.6301 - val_loss: 146.9563
# Epoch 91/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 144.5663 - val_loss: 146.8456
# Epoch 92/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 144.5538 - val_loss: 146.5712
# Epoch 93/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 144.5053 - val_loss: 147.1533
# Epoch 94/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 144.5063 - val_loss: 146.7139
# Epoch 95/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 144.4505 - val_loss: 146.5004
# Epoch 96/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 144.4304 - val_loss: 146.4971
# Epoch 97/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 144.4184 - val_loss: 146.5685
# Epoch 98/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 144.3718 - val_loss: 146.4069
# Epoch 99/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 144.3956 - val_loss: 146.5277
# Epoch 100/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 144.3494 - val_loss: 146.6921

# %%
x_test_encoded = encoder.predict(x_test, batch_size=32)
plt.figure(figsize=(6, 6))
plt.scatter(x_test_encoded[0][:, 0], x_test_encoded[0][:, 1], c=y_test)
plt.colorbar()
plt.show()
# Out:
# 192/313 [=================>............] - ETA: 0s
# 313/313 [==============================] - 0s 1ms/step

# %%
# Display a 2D manifold of the digits
n = 15  # figure with 15x15 digits
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))
# We will sample n points within [-15, 15] standard deviations
grid_x = np.linspace(-15, 15, n)
grid_y = np.linspace(-15, 15, n)

for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        x_decoded = decoder.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit

plt.figure(figsize=(10, 10))
plt.imshow(figure)
plt.show()
# Out:
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
